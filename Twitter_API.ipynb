# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
from twython import Twython

# Load credentials from json file
with open("twitter_credentials.json", "r") as file:  
    creds = json.load(file)
    
# Instantiate an object
python_tweets = Twython(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])


# Create our query
query = {'q': 'Berlin',  
        'count': 30,
        }

# Search tweets
dict_ = {'user': [],'friends_count':[], 'date': [], 'text': [], 'favorite_count': [],
         'retweet_count':[],"retweeted":[],"user_loc": [],"lang": [],}

try:
    for status in python_tweets.search(**query)['statuses']:  
        dict_['user'].append(status['user']['screen_name'])
        dict_['user_loc'].append(status['user']['location'])
        dict_['friends_count'].append(status['user']['friends_count'])
        dict_['date'].append(status['created_at'])
        dict_['text'].append(status['text'])
        dict_['favorite_count'].append(status['favorite_count'])
        dict_['retweet_count'].append(status['retweet_count'])
        dict_['retweeted'].append(status['retweeted'])
        dict_['lang'].append(status['lang'])
    # Structure data in a pandas DataFrame for easier manipulation
    df = pd.DataFrame(dict_)  
    df.sort_values(by='favorite_count', inplace=True, ascending=False)  
except TwythonError as e:
    print(e)

# %%
df.head(20)
# Out:
#                               date  favorite_count  friends_count lang  \
# 0   Thu Jun 14 17:16:56 +0000 2018               0           6585   de
# 1   Thu Jun 14 17:16:54 +0000 2018               0            136   sl
# 28  Thu Jun 14 17:16:26 +0000 2018               0            115   es
# 27  Thu Jun 14 17:16:29 +0000 2018               0            483   en
# 26  Thu Jun 14 17:16:30 +0000 2018               0           5002   en
# 25  Thu Jun 14 17:16:33 +0000 2018               0           1056  und
# 24  Thu Jun 14 17:16:33 +0000 2018               0           1574   en
# 23  Thu Jun 14 17:16:34 +0000 2018               0            378   es
# 22  Thu Jun 14 17:16:34 +0000 2018               0            480   en
# 21  Thu Jun 14 17:16:35 +0000 2018               0           3549   en
# 20  Thu Jun 14 17:16:35 +0000 2018               0            621   fr
# 19  Thu Jun 14 17:16:36 +0000 2018               0            372   en
# 18  Thu Jun 14 17:16:36 +0000 2018               0             52   es
# 17  Thu Jun 14 17:16:37 +0000 2018               0            257   en
# 16  Thu Jun 14 17:16:39 +0000 2018               0            781   en
# 15  Thu Jun 14 17:16:39 +0000 2018               0           1138   de
# 14  Thu Jun 14 17:16:40 +0000 2018               0            534   ja
# 13  Thu Jun 14 17:16:42 +0000 2018               0          15038   de
# 12  Thu Jun 14 17:16:43 +0000 2018               0            669   en
# 11  Thu Jun 14 17:16:44 +0000 2018               0            310   in
#
#     retweet_count  retweeted  \
# 0               9      False
# 1               1      False
# 28             15      False
# 27            478      False
# 26             28      False
# 25              1      False
# 24              0      False
# 23             75      False
# 22              0      False
# 21            478      False
# 20            283      False
# 19              0      False
# 18            482      False
# 17          41918      False
# 16            478      False
# 15              0      False
# 14              0      False
# 13             15      False
# 12              0      False
# 11              0      False
#
#                                                  text             user  \
# 0   RT @orbisclaudiae: BERLINER! Freunde von mir s...      Mailwurm666
# 1   RT @Miran7777: HAHAHAHA !\n\nDOČAKALI SMO TA D...    IvankaKoprivc
# 28  RT @GuajeSalvaje: El sentido del humor de TV3....   Isabel17109898
# 27  RT @YouTH_1117: [4K] 180608 ‘EYES ON YOU’ BERL...          Nae_Nie
# 26  RT @GermanyDiplo: FM @HeikoMaas congratulates ...          jk55044
# 25  RT @OliverKulikBln: #Katharina #EsReicht\n\nht...    CroqiSunshine
# 24  We are so glad to attend such an inspiring con...    suleyucebiyik
# 23  RT @LogiaBilardista: Desde el Ejército Rojo en...   LeanFernandez7
# 22  @airfrance I need my additional luggage to be ...        LadyFeroz
# 21  RT @YouTH_1117: [4K] 180608 ‘EYES ON YOU’ BERL...  otter_youngjae7
# 20  RT @FCOUILBAULT1: Un axe Rome Vienne Berlin so...            mxd31
# 19  @ConStelz @AlexLuck9 @Breitbart What a coincid...           AlbKol
# 18  RT @MistralS: Anda, como en el 39 : Los minist...      fern_florez
# 17  RT @GOT7Official: [ #GOT7NOW ] See you tomorro...       cyamzjtwya
# 16  RT @YouTH_1117: [4K] 180608 ‘EYES ON YOU’ BERL...           blxwee
# 15  Dit is Berlin #servicetweet (...und das ist nu...  JeanneKinderman
# 14                          @Berlin_130loly おらかえよおらおら       chaosR1081
# 13  RT @JFDA_eV: #Antisemitismus auf Plakaten und ...    yoga_and_more
# 12  My interview in the Kurt Weill newsletter -  o...     GenePritsker
# 11                                    Berlin, Berlin.         Herzdame
#
#                         user_loc
# 0                         D. NRW
# 1
# 28
# 27             Bangkok, Thailand
# 26
# 25            Bunde/Ostfriesland
# 24                      istanbul
# 23
# 22                     Hong Kong
# 21  5/5+ronnie, james+luke faved
# 20
# 19
# 18
# 17
# 16                   ในใจคยอมดูง
# 15       Düsseldorf, Deutschland
# 14                    chaos(カオス)
# 13
# 12                           USA
# 11              Hamburg, Germany
