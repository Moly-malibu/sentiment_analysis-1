# %%
import numpy as np
import csv
import pandas_datareader as pdr
import datetime
# Out:
# /home/javier/anaconda3/envs/py35/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/javier/anaconda3/envs/py35/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
aapl = pdr.get_data_quandl('TSLA', 
                          start=datetime.datetime(2015, 8, 1), 
                          end=datetime.datetime(2015, 8, 30))

# %%
aapl
# Out:
#               Open      High       Low   Close      Volume  ExDividend  \
# Date
# 2015-08-28  241.86  251.4500  241.5700  248.48   5513673.0         0.0
# 2015-08-27  231.00  244.7500  230.8100  242.99   7655959.0         0.0
# 2015-08-26  227.93  228.0000  215.5100  224.84   4963042.0         0.0
# 2015-08-25  230.52  230.9000  219.1200  220.03   4327294.0         0.0
# 2015-08-24  202.79  231.4000  195.0000  218.87   9581585.0         0.0
# 2015-08-21  236.00  243.7999  230.5100  230.77   6590234.0         0.0
# 2015-08-20  252.06  254.5600  241.9000  242.18   4905757.0         0.0
# 2015-08-19  260.33  260.6500  255.0200  255.25   3604282.0         0.0
# 2015-08-18  255.38  260.9500  253.5601  260.72   4195035.0         0.0
# 2015-08-17  255.56  256.5900  250.5100  254.99   7176690.0         0.0
# 2015-08-14  247.24  247.9300  241.7700  243.15   4364810.0         0.0
# 2015-08-13  239.86  246.4800  239.1200  242.51   4689182.0         0.0
# ...

# %%
pandas_datareader.quandl.QuandlReader('TSLA',, start=None, end=None, retry_count=3, pause=0.1, session=None, chunksize=25, api_key=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-9c3ae41b370a> in <module>()
# ----> 1 plt.plot(appl)
#
# NameError: name 'plt' is not defined
